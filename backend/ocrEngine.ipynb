# %%
import pandas as pd

# %%
premium_ws=pd.read_excel(
    "bordereaux.xlsx", 
    engine='openpyxl', 
    sheet_name='Premium Bordereaux'
    )

claims_ws=pd.read_excel(
    "bordereaux.xlsx", 
    engine='openpyxl', 
    sheet_name='Claims Bordereaux'
    )

# %%
print(premium_ws.head())
# Out:
#                  Policy Holder ID  Principal beneficiary Dependants  \
# 0                             NaN                    NaN        NaN
# 1  AMBASSADEUR KWIZERA DIEUDONNE                     1.0          0
# 2                  CHIRO BURUNDI                     8.0         11
# 3    CENTRE BURUNDAIS D INTERNET                    39.0         99
# 4                NTAHONDEREYE DEO                    1.0          0
#
#    Total beneficiaries   Police ID  Start Date of Cover End Date of Cover  \
# 0                  NaN         NaN                  NaN               NaT
# 1                  1.0  20000019.0  2020-07-01 00:00:00        2021-06-30
# 2                 19.0  20000021.0  2020-07-17 00:00:00        2020-10-16
# 3                138.0  20000022.0  2020-07-01 00:00:00        2021-06-30
# 4                  1.0  20000023.0  2020-08-05 00:00:00        2021-08-04
#
#                                                              Unnamed: 8  \
# 0  Full Annual Premium Payable  Number of  payment Installments allowed
# 1                      1638558                                        1
# 2                      2315283                                        1
# 3                     37030503                                        4
# 4                       968957                                        1
#
#                         Unnamed: 9                 Unnamed: 10  \
# 0  Amount payable Per Installment   Total Premium paid to date
# 1                          1638558                     1638558
# 2                          2315283                     2315283
# 3                          9257626                    37030503
# 4                           968957                      968957
#
#                     Unnamed: 11  Premium Amount                Benefit Limit  \
# 0  Outstanding premium Balance              NaN  Limit Outpatient per family
# 1                           NaN       1638558.0                      1200000
# 2                           NaN       2315283.0                       500000
# 3                           NaN      37030503.0                      2000000
# 4                           NaN        968957.0                      1500000
#
#                   Unnamed: 14                  Unnamed: 15  \
# 0  Limit inpatient per family  Limit Dental per individual
# 1                     8000000                       250000
# 2                     3000000                       150000
# 3                     6000000                       300000
# 4                     8000000                       250000
#
#                   Unnamed: 16                           Unnamed: 17  \
# 0  Limit optic per individual  Limit spectacle frame per individual
# 1                      250000                                100000
# 2                      150000                                 50000
# 3                      250000                                150000
# 4                      250000                                100000
#
#                                          Unnamed: 18  Premium Paid/Billed
# 0  Death and total permanent disability cover per...                  NaN
# 1                                            5000000            1638558.0
# 2                                            3500000            2315283.0
# 3                                            1000000           37030503.0
# 4                                            5000000             968957.0

# %%
print(claims_ws.head())
# Out:
#                      Policy Holder ID        Member ID Start Date of Cover  \
# 0                                 NaN              NaN                 NaT
# 1                                 NaN              NaN                 NaT
# 2  ALLIANCE BURUNDAISE CONTRE LE SIDA  NISUBIRE GERARD          2020-06-01
# 3                                 NaN  NISUBIRE GERARD          2020-06-01
# 4                                 NaN  NAHAYO CLAUDINE          2020-06-01
#
#   End Date of Cover Date of Claim/Treatment Date  \
# 0               NaT                          NaN
# 1               NaT                          NaN
# 2        2021-05-31                   2020-07-01
# 3        2021-05-31                   2020-07-01
# 4        2021-05-31                   2020-07-03
#
#   Date of Payment/Approval Date         Amount Claimed            Unnamed: 7  \
# 0                           NaN  Outpatient per family  Inpatient per family
# 1                           NaN                    NaN                   NaN
# 2                    2020-07-01                  10000                   NaN
# 3                    2020-07-01                   9100                   NaN
# 4                    2020-07-03                 212000                   NaN
#
#               Unnamed: 8             Unnamed: 9  ...  \
# 0  Dental per individual   optic per individual  ...
# 1                    NaN                    NaN  ...
# 2                    NaN                    NaN  ...
# 3                    NaN                    NaN  ...
# 4                    NaN                    NaN  ...
#
#                       Unnamed: 16  \
# 0  spectacle frame per individual
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                                          Unnamed: 17        Unnamed: 18  \
# 0  Death and total permanent disability cover per...  Total claims Paid
# 1                                                NaN                NaN
# 2                                                NaN              10000
# 3                                                NaN               9100
# 4                                                NaN             212000
#
#                  Benefit Limit                 Unnamed: 20  \
# 0  Limit Outpatient per family  Limit inpatient per family
# 1                          NaN                         NaN
# 2                      1200000                     8000000
# 3                      1200000                     8000000
# 4                      1200000                     8000000
#
#                    Unnamed: 21                 Unnamed: 22  \
# 0  Limit Dental per individual  Limit optic per individual
# 1                          NaN                         NaN
# 2                       250000                      250000
# 3                       250000                      250000
# 4                       250000                      250000
#
#                             Unnamed: 23  \
# 0  Limit spectacle frame per individual
# 1                                   NaN
# 2                                100000
# 3                                100000
# 4                                100000
#
#                                          Unnamed: 24  \
# 0  Death and total permanent disability cover per...
# 1                                                NaN
# 2                                            3500000
# 3                                            3500000
# 4                                            3500000
#
#               Provider Name/Code
# 0                            NaN
# 1                            NaN
# 2  CLINIQUE D OPHTALMOLOGIE IRIS
# 3        PHARMACIE SALAMA siège
# 4        PHARMACIE SALAMA siège
#
# [5 rows x 26 columns]
